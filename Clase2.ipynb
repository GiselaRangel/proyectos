# %%
from pylab import *
# %matplotlib inline

# %%
def func (x):
    #tabs son importantes!
    y = x**2
    return y

# %%
x = linspace(0,2)

# %%
plot(x,func(x))

# %%
def func2 (a):
    #tabs son importantes!
    x = linspace(0,a)
    y = x**3
    plot(x,y)

# %%
func2(1)

# %%
a = "hola mundo"
def hola():
    a =  "hola de nuevo"
    print a
print a
hola()
# Out:
# hola mundo
# hola de nuevo

# %%
plot(x,func (x),x,func2(x))
xlim(0,1)
ylim(0,1)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-46-9d6fdc63c7a1> in <module>()
# ----> 1 plot(x,func (x),x,func2(x))
#       2 xlim(0,1)
#       3 ylim(0,1)
#
# <ipython-input-44-fcb221986374> in func2(a)
#       1 def func2 (a):
#       2     #tabs son importantes!
# ----> 3     x = linspace(0,a)
#       4     y = x**3
#       5     plot(x,y)
#
# C:\Users\EDITH\Anaconda2\lib\site-packages\numpy\core\function_base.pyc in linspace(start, stop, num, endpoint, retstep, dtype)
#     118     if num > 1:
#     119         step = delta / div
# --> 120         if step == 0:
#     121             # Special handling for denormal numbers, gh-5437
#     122             y /= div
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
x = linspace(0,6) 
puntosy = [1,3,2,5,0.2]
puntosx = [0,1,2,3,4]
plot(puntosx, puntosy, 'o')
plot(x,func(x))

# %%
def func3(x,exponente):
    return x**exponente

# %%
for i in range(8):
    y = func3(x,i)
    plot(x,y)

# %%
range (3)
# Out:
# [0, 1, 2]

# %% [raw]
# arange (0,1,5,0.5)

# %%
platillos = [100,130,30]
len(platillos)
# Out:
# 3

# %%
def cuenta(platillos, propina):
    total= 0
    for i in range (len(platillos)):
        total += platillos[i]
    
    total = total + total*propina
    print total

# %%
platillos = [50,23,40,121,154]
propina = 0.11
cuenta(platillos,propina)
# Out:
# 430.68
